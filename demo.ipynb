# %%
# Run this cell if you are using from colab
# !wget https://raw.githubusercontent.com/phuijse/colab_template/main/data.parquet
# !pip install my_package.wheel

# %%
import polars as pl
import numpy as np
from matplotlib import pyplot as plt

# %%
t, y = pl.read_parquet('data.parquet').to_numpy().T

plt.plot(t, y)

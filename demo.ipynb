# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/phuijse/colab_example/blob/main/demo.ipynb)

# %%
import polars as pl
import numpy as np
from matplotlib import pyplot as plt

# %%
t, y = pl.read_parquet('data.parquet').to_numpy().T

plt.plot(t, y)
